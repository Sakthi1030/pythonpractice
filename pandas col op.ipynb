# %%
import pandas as pd
df = pd.read_csv('U.S. Home Sales 1963-2016.csv',sep =',')
df
# Out:
#        per_idx    per_name  cat_idx cat_code  \
# 0            1  1963-01-01        1     SOLD
# 1            1  1963-01-01        1     SOLD
# 2            1  1963-01-01        1     SOLD
# 3            1  1963-01-01        1     SOLD
# 4            1  1963-01-01        1     SOLD
# ...        ...         ...      ...      ...
# 20399      646  2016-10-01        3  FORSALE
# 20400      646  2016-10-01        3  FORSALE
# 20401      646  2016-10-01        3  FORSALE
# 20402      646  2016-10-01        3  FORSALE
# 20403      646  2016-10-01        3  FORSALE
#
#                                 cat_desc  cat_indent  dt_idx dt_code  \
# 0          New Single-family Houses Sold           0       5  MEDIAN
# 1          New Single-family Houses Sold           0       2  NOTSTD
# 2          New Single-family Houses Sold           0       3  UNDERC
# 3          New Single-family Houses Sold           0       4  COMPED
# 4          New Single-family Houses Sold           0       1   TOTAL
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20404 entries, 0 to 20403
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   per_idx     20404 non-null  int64
#  1   per_name    20404 non-null  object
#  2   cat_idx     20404 non-null  int64
#  3   cat_code    20404 non-null  object
#  4   cat_desc    20404 non-null  object
#  5   cat_indent  20404 non-null  int64
#  6   dt_idx      20404 non-null  int64
#  7   dt_code     15354 non-null  object
#  8   dt_desc     15354 non-null  object
#  9   dt_unit     15354 non-null  object
#  10  et_idx      20404 non-null  int64
#  11  et_code     5050 non-null   object
#  12  et_desc     5050 non-null   object
#  13  et_unit     5050 non-null   object
#  14  geo_idx     20404 non-null  int64
#  15  geo_code    20404 non-null  object
#  16  geo_desc    20404 non-null  object
#  17  is_adj      20404 non-null  int64
#  18  val         18610 non-null  float64
# ...

# %%
df.describe()
# Out:
#             per_idx       cat_idx  cat_indent        dt_idx        et_idx  \
# count  20404.000000  20404.000000     20404.0  20404.000000  20404.000000
# mean     405.189277      2.045677         0.0      1.898941      0.584101
# std      170.217740      0.902040         0.0      2.202395      1.450598
# min        1.000000      1.000000         0.0      0.000000      0.000000
# 25%      267.000000      1.000000         0.0      1.000000      0.000000
# 50%      450.000000      2.000000         0.0      1.000000      0.000000
# 75%      548.000000      3.000000         0.0      3.000000      0.000000
# max      646.000000      3.000000         0.0      8.000000      8.000000
#
#             geo_idx        is_adj            val      serialid
# count  20404.000000  20404.000000   18610.000000  20404.000000
# mean       2.070378      0.247599    9352.033638  10202.500000
# std        1.437194      0.431628   42851.074035   5890.271782
# ...

# %%
df.head(10)
# Out:
#    per_idx    per_name  cat_idx cat_code  \
# 0        1  1963-01-01        1     SOLD
# 1        1  1963-01-01        1     SOLD
# 2        1  1963-01-01        1     SOLD
# 3        1  1963-01-01        1     SOLD
# 4        1  1963-01-01        1     SOLD
# 5        1  1963-01-01        2    ASOLD
# 6        1  1963-01-01        3  FORSALE
# 7        1  1963-01-01        3  FORSALE
# 8        1  1963-01-01        3  FORSALE
# 9        1  1963-01-01        3  FORSALE
#
#                                         cat_desc  cat_indent  dt_idx dt_code  \
# 0                  New Single-family Houses Sold           0       5  MEDIAN
# 1                  New Single-family Houses Sold           0       2  NOTSTD
# 2                  New Single-family Houses Sold           0       3  UNDERC
# 3                  New Single-family Houses Sold           0       4  COMPED
# 4                  New Single-family Houses Sold           0       1   TOTAL
# ...

# %%
df.tail(10)
# Out:
#        per_idx    per_name  cat_idx cat_code  \
# 20394      646  2016-10-01        3  FORSALE
# 20395      646  2016-10-01        3  FORSALE
# 20396      646  2016-10-01        3  FORSALE
# 20397      646  2016-10-01        3  FORSALE
# 20398      646  2016-10-01        3  FORSALE
# 20399      646  2016-10-01        3  FORSALE
# 20400      646  2016-10-01        3  FORSALE
# 20401      646  2016-10-01        3  FORSALE
# 20402      646  2016-10-01        3  FORSALE
# 20403      646  2016-10-01        3  FORSALE
#
#                                 cat_desc  cat_indent  dt_idx dt_code  \
# 20394  New Single-family Houses For Sale           0       1   TOTAL
# 20395  New Single-family Houses For Sale           0       1   TOTAL
# 20396  New Single-family Houses For Sale           0       0     NaN
# 20397  New Single-family Houses For Sale           0       1   TOTAL
# 20398  New Single-family Houses For Sale           0       0     NaN
# ...

# %%
df.shape
# Out:
# (20404, 20)

# %%
df = df[df['cat_code'] == 'SOLD']
df
# Out:
#        per_idx    per_name  cat_idx cat_code                       cat_desc  \
# 0            1  1963-01-01        1     SOLD  New Single-family Houses Sold
# 1            1  1963-01-01        1     SOLD  New Single-family Houses Sold
# 2            1  1963-01-01        1     SOLD  New Single-family Houses Sold
# 3            1  1963-01-01        1     SOLD  New Single-family Houses Sold
# 4            1  1963-01-01        1     SOLD  New Single-family Houses Sold
# ...        ...         ...      ...      ...                            ...
# 20373      646  2016-10-01        1     SOLD  New Single-family Houses Sold
# 20375      646  2016-10-01        1     SOLD  New Single-family Houses Sold
# 20377      646  2016-10-01        1     SOLD  New Single-family Houses Sold
# 20379      646  2016-10-01        1     SOLD  New Single-family Houses Sold
# 20381      646  2016-10-01        1     SOLD  New Single-family Houses Sold
#
# ...

# %%
df= df[df['dt_code'] == 'MEDIAN']
df
# Out:
#        per_idx    per_name  cat_idx cat_code                       cat_desc  \
# 0            1  1963-01-01        1     SOLD  New Single-family Houses Sold
# 10           2  1963-02-01        1     SOLD  New Single-family Houses Sold
# 20           3  1963-03-01        1     SOLD  New Single-family Houses Sold
# 30           4  1963-04-01        1     SOLD  New Single-family Houses Sold
# 40           5  1963-05-01        1     SOLD  New Single-family Houses Sold
# ...        ...         ...      ...      ...                            ...
# 20146      642  2016-06-01        1     SOLD  New Single-family Houses Sold
# 20198      643  2016-07-01        1     SOLD  New Single-family Houses Sold
# 20250      644  2016-08-01        1     SOLD  New Single-family Houses Sold
# 20302      645  2016-09-01        1     SOLD  New Single-family Houses Sold
# 20355      646  2016-10-01        1     SOLD  New Single-family Houses Sold
#
# ...

# %%
# !jt -l
# Out:
# Available Themes:
#    chesterish
#    grade3
#    gruvboxd
#    gruvboxl
#    monokai
#    oceans16
#    onedork
#    solarizedd
#    solarizedl

# %%
# !jt -t  gruvboxd -f ptsans -fs 15  -T

# %%
df = df[(df['dt_code']!= 'MEDIAN')
        &(df['dt_code']!= 'NOBTD')]
df
# Out:
#        per_idx    per_name  cat_idx cat_code  \
# 1            1  1963-01-01        1     SOLD
# 2            1  1963-01-01        1     SOLD
# 3            1  1963-01-01        1     SOLD
# 4            1  1963-01-01        1     SOLD
# 5            1  1963-01-01        2    ASOLD
# ...        ...         ...      ...      ...
# 20399      646  2016-10-01        3  FORSALE
# 20400      646  2016-10-01        3  FORSALE
# 20401      646  2016-10-01        3  FORSALE
# 20402      646  2016-10-01        3  FORSALE
# 20403      646  2016-10-01        3  FORSALE
#
#                                             cat_desc  cat_indent  dt_idx  \
# 1                      New Single-family Houses Sold           0       2
# 2                      New Single-family Houses Sold           0       3
# 3                      New Single-family Houses Sold           0       4
# 4                      New Single-family Houses Sold           0       1
# ...

# %%
df = df[pd.notnull(df['dt_code'])]
df
# Out:
#        per_idx    per_name  cat_idx cat_code  \
# 1            1  1963-01-01        1     SOLD
# 2            1  1963-01-01        1     SOLD
# 3            1  1963-01-01        1     SOLD
# 4            1  1963-01-01        1     SOLD
# 5            1  1963-01-01        2    ASOLD
# ...        ...         ...      ...      ...
# 20394      646  2016-10-01        3  FORSALE
# 20395      646  2016-10-01        3  FORSALE
# 20397      646  2016-10-01        3  FORSALE
# 20399      646  2016-10-01        3  FORSALE
# 20401      646  2016-10-01        3  FORSALE
#
#                                             cat_desc  cat_indent  dt_idx  \
# 1                      New Single-family Houses Sold           0       2
# 2                      New Single-family Houses Sold           0       3
# 3                      New Single-family Houses Sold           0       4
# 4                      New Single-family Houses Sold           0       1
# ...

# %%
df_un = df[df['dt_code']=='UNDERC']
df_un
# Out:
#        per_idx    per_name  cat_idx cat_code  \
# 2            1  1963-01-01        1     SOLD
# 12           2  1963-02-01        1     SOLD
# 22           3  1963-03-01        1     SOLD
# 32           4  1963-04-01        1     SOLD
# 42           5  1963-05-01        1     SOLD
# ...        ...         ...      ...      ...
# 20285      644  2016-08-01        3  FORSALE
# 20306      645  2016-09-01        1     SOLD
# 20338      645  2016-09-01        3  FORSALE
# 20359      646  2016-10-01        1     SOLD
# 20390      646  2016-10-01        3  FORSALE
#
#                                 cat_desc  cat_indent  dt_idx dt_code  \
# 2          New Single-family Houses Sold           0       3  UNDERC
# 12         New Single-family Houses Sold           0       3  UNDERC
# 22         New Single-family Houses Sold           0       3  UNDERC
# 32         New Single-family Houses Sold           0       3  UNDERC
# 42         New Single-family Houses Sold           0       3  UNDERC
# ...

# %%
df_com = df[df['dt_code']=='COMPED']
df_com
# Out:
#        per_idx    per_name  cat_idx cat_code  \
# 3            1  1963-01-01        1     SOLD
# 13           2  1963-02-01        1     SOLD
# 23           3  1963-03-01        1     SOLD
# 33           4  1963-04-01        1     SOLD
# 43           5  1963-05-01        1     SOLD
# ...        ...         ...      ...      ...
# 20287      644  2016-08-01        3  FORSALE
# 20308      645  2016-09-01        1     SOLD
# 20340      645  2016-09-01        3  FORSALE
# 20361      646  2016-10-01        1     SOLD
# 20392      646  2016-10-01        3  FORSALE
#
#                                 cat_desc  cat_indent  dt_idx dt_code  \
# 3          New Single-family Houses Sold           0       4  COMPED
# 13         New Single-family Houses Sold           0       4  COMPED
# 23         New Single-family Houses Sold           0       4  COMPED
# 33         New Single-family Houses Sold           0       4  COMPED
# 43         New Single-family Houses Sold           0       4  COMPED
# ...

# %%
df_avd = df[df['dt_code']=='AVERAGE']
df_avd
# Out:
# Empty DataFrame
# Columns: [per_idx, per_name, cat_idx, cat_code, cat_desc, cat_indent, dt_idx, dt_code, dt_desc, dt_unit, et_idx, et_code, et_desc, et_unit, geo_idx, geo_code, geo_desc, is_adj, val, serialid]
# Index: []
